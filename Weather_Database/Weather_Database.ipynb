# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90, 90, size = 2000)
lngs = np.random.uniform(-180, 180, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 760

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+") 
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"] 
        city_weather_description = city_weather["weather"][0]["description"]   
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Weather Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | alofi
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | richards bay
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | kaeo
# Processing Record 6 of Set 1 | avarua
# Processing Record 7 of Set 1 | saint-augustin
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 10 of Set 1 | san patricio
# Processing Record 11 of Set 1 | peniche
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | lata
# Processing Record 15 of Set 1 | klaksvik
# Processing Record 16 of Set 1 | paamiut
# Processing Record 17 of Set 1 | saint george
# Processing Record 18 of Set 1 | esperance
# Processing Record 19 of Set 1 | la ronge
# Processing Record 20 of Set 1 | bengkulu
# Processing Record 21 of Set 1 | iqaluit
# Processing Record 22 of Set 1 | tasiilaq
# Processing Record 23 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | kintampo
# Processing Record 26 of Set 1 | saskylakh
# Processing Record 27 of Set 1 | ponta do sol
# Processing Record 28 of Set 1 | olafsvik
# Processing Record 29 of Set 1 | vaitape
# Processing Record 30 of Set 1 | kavaratti
# Processing Record 31 of Set 1 | chihuahua
# Processing Record 32 of Set 1 | kulhudhuffushi
# Processing Record 33 of Set 1 | falmouth
# Processing Record 34 of Set 1 | sheffield
# Processing Record 35 of Set 1 | mount isa
# Processing Record 36 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 1 | soldatskiy
# City not found. Skipping...
# Processing Record 38 of Set 1 | georgetown
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | castro
# Processing Record 41 of Set 1 | talnakh
# Processing Record 42 of Set 1 | half moon bay
# Processing Record 43 of Set 1 | kutum
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | souillac
# Processing Record 46 of Set 1 | lagoa
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | natal
# Processing Record 49 of Set 1 | goderich
# Processing Record 50 of Set 1 | longyearbyen
# Processing Record 1 of Set 2 | sao filipe
# Processing Record 2 of Set 2 | grand-santi
# Processing Record 3 of Set 2 | fortuna
# Processing Record 4 of Set 2 | thompson
# Processing Record 5 of Set 2 | suntar
# Processing Record 6 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 2 | rincon
# Processing Record 8 of Set 2 | pochutla
# Processing Record 9 of Set 2 | kapit
# Processing Record 10 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 2 | zaysan
# Processing Record 12 of Set 2 | tagbac
# Processing Record 13 of Set 2 | ribeira grande
# Processing Record 14 of Set 2 | quatre cocos
# Processing Record 15 of Set 2 | punta arenas
# Processing Record 16 of Set 2 | touros
# Processing Record 17 of Set 2 | jamestown
# Processing Record 18 of Set 2 | tiksi
# Processing Record 19 of Set 2 | lavrentiya
# Processing Record 20 of Set 2 | vardo
# Processing Record 21 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 2 | narsaq
# Processing Record 23 of Set 2 | butaritari
# Processing Record 24 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 2 | oriximina
# Processing Record 26 of Set 2 | meulaboh
# Processing Record 27 of Set 2 | monterey
# Processing Record 28 of Set 2 | atuona
# Processing Record 29 of Set 2 | albany
# Processing Record 30 of Set 2 | malindi
# Processing Record 31 of Set 2 | new norfolk
# Processing Record 32 of Set 2 | hobart
# Processing Record 33 of Set 2 | turukhansk
# Processing Record 34 of Set 2 | puerto ayora
# Processing Record 35 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 2 | upernavik
# Processing Record 37 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 2 | belmonte
# Processing Record 39 of Set 2 | ilulissat
# Processing Record 40 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 2 | erzin
# Processing Record 42 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 2 | kawana waters
# City not found. Skipping...
# Processing Record 44 of Set 2 | norman wells
# Processing Record 45 of Set 2 | severo-kurilsk
# Processing Record 46 of Set 2 | daitari
# Processing Record 47 of Set 2 | yellowknife
# Processing Record 48 of Set 2 | acapulco
# Processing Record 49 of Set 2 | leningradskiy
# Processing Record 50 of Set 2 | zalantun
# Processing Record 1 of Set 3 | rio verde de mato grosso
# Processing Record 2 of Set 3 | cape town
# Processing Record 3 of Set 3 | muros
# Processing Record 4 of Set 3 | bethel
# Processing Record 5 of Set 3 | houma
# Processing Record 6 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 3 | cidreira
# Processing Record 8 of Set 3 | saint-philippe
# Processing Record 9 of Set 3 | mecca
# Processing Record 10 of Set 3 | hoquiam
# Processing Record 11 of Set 3 | nieuwpoort
# Processing Record 12 of Set 3 | popondetta
# Processing Record 13 of Set 3 | totness
# Processing Record 14 of Set 3 | chokurdakh
# Processing Record 15 of Set 3 | bredasdorp
# Processing Record 16 of Set 3 | san pablo
# Processing Record 17 of Set 3 | abu kamal
# Processing Record 18 of Set 3 | storm lake
# Processing Record 19 of Set 3 | karratha
# Processing Record 20 of Set 3 | mar del plata
# Processing Record 21 of Set 3 | airai
# Processing Record 22 of Set 3 | hermanus
# Processing Record 23 of Set 3 | haines junction
# Processing Record 24 of Set 3 | qaanaaq
# Processing Record 25 of Set 3 | guerrero negro
# Processing Record 26 of Set 3 | east london
# Processing Record 27 of Set 3 | noumea
# Processing Record 28 of Set 3 | sirvintos
# Processing Record 29 of Set 3 | camacha
# Processing Record 30 of Set 3 | nazarovo
# Processing Record 31 of Set 3 | wuchang
# Processing Record 32 of Set 3 | gornopravdinsk
# Processing Record 33 of Set 3 | ketchikan
# Processing Record 34 of Set 3 | mersin
# Processing Record 35 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 3 | lufilufi
# Processing Record 37 of Set 3 | lompoc
# Processing Record 38 of Set 3 | mehkar
# Processing Record 39 of Set 3 | clyde river
# Processing Record 40 of Set 3 | hofn
# Processing Record 41 of Set 3 | north bend
# Processing Record 42 of Set 3 | cabo san lucas
# Processing Record 43 of Set 3 | puerto escondido
# Processing Record 44 of Set 3 | pevek
# Processing Record 45 of Set 3 | khatanga
# Processing Record 46 of Set 3 | vao
# Processing Record 47 of Set 3 | nome
# Processing Record 48 of Set 3 | ust-kuyga
# Processing Record 49 of Set 3 | dikson
# Processing Record 50 of Set 3 | ipilan
# Processing Record 1 of Set 4 | rabwah
# City not found. Skipping...
# Processing Record 2 of Set 4 | rio grande
# Processing Record 3 of Set 4 | umm kaddadah
# Processing Record 4 of Set 4 | hamilton
# Processing Record 5 of Set 4 | pouembout
# Processing Record 6 of Set 4 | kavieng
# Processing Record 7 of Set 4 | dalian
# Processing Record 8 of Set 4 | parabel
# Processing Record 9 of Set 4 | deputatskiy
# Processing Record 10 of Set 4 | hithadhoo
# Processing Record 11 of Set 4 | baghmara
# Processing Record 12 of Set 4 | san cristobal
# Processing Record 13 of Set 4 | pedasi
# Processing Record 14 of Set 4 | atar
# Processing Record 15 of Set 4 | nautla
# Processing Record 16 of Set 4 | kalmunai
# Processing Record 17 of Set 4 | hilo
# Processing Record 18 of Set 4 | san lorenzo
# Processing Record 19 of Set 4 | mahebourg
# Processing Record 20 of Set 4 | kodiak
# Processing Record 21 of Set 4 | tessalit
# Processing Record 22 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 4 | viedma
# Processing Record 24 of Set 4 | shimoda
# Processing Record 25 of Set 4 | chuy
# Processing Record 26 of Set 4 | aguas vermelhas
# Processing Record 27 of Set 4 | cherskiy
# Processing Record 28 of Set 4 | arica
# Processing Record 29 of Set 4 | maple creek
# Processing Record 30 of Set 4 | dongsheng
# Processing Record 31 of Set 4 | hambantota
# Processing Record 32 of Set 4 | lashio
# Processing Record 33 of Set 4 | ust-omchug
# Processing Record 34 of Set 4 | havre-saint-pierre
# Processing Record 35 of Set 4 | japura
# Processing Record 36 of Set 4 | vama buzaului
# City not found. Skipping...
# Processing Record 37 of Set 4 | kaitangata
# Processing Record 38 of Set 4 | torbay
# Processing Record 39 of Set 4 | okha
# Processing Record 40 of Set 4 | evensk
# Processing Record 41 of Set 4 | valreas
# Processing Record 42 of Set 4 | vieste
# Processing Record 43 of Set 4 | longonjo
# Processing Record 44 of Set 4 | luderitz
# Processing Record 45 of Set 4 | kindu
# Processing Record 46 of Set 4 | riyadh
# Processing Record 47 of Set 4 | svetlogorsk
# Processing Record 48 of Set 4 | geraldton
# Processing Record 49 of Set 4 | semey
# Processing Record 50 of Set 4 | isangel
# Processing Record 1 of Set 5 | glendive
# Processing Record 2 of Set 5 | codrington
# Processing Record 3 of Set 5 | anloga
# Processing Record 4 of Set 5 | te anau
# Processing Record 5 of Set 5 | bonavista
# Processing Record 6 of Set 5 | guiglo
# Processing Record 7 of Set 5 | cockburn town
# Processing Record 8 of Set 5 | sao joao da barra
# Processing Record 9 of Set 5 | jiazi
# Processing Record 10 of Set 5 | port-gentil
# Processing Record 11 of Set 5 | bathsheba
# Processing Record 12 of Set 5 | gaogou
# Processing Record 13 of Set 5 | saint-denis
# Processing Record 14 of Set 5 | safaga
# Processing Record 15 of Set 5 | outlook
# Processing Record 16 of Set 5 | pribinic
# Processing Record 17 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 18 of Set 5 | vostok
# Processing Record 19 of Set 5 | ca mau
# Processing Record 20 of Set 5 | vitry-le-francois
# Processing Record 21 of Set 5 | provideniya
# Processing Record 22 of Set 5 | nacogdoches
# Processing Record 23 of Set 5 | nantucket
# Processing Record 24 of Set 5 | taoudenni
# Processing Record 25 of Set 5 | berlevag
# Processing Record 26 of Set 5 | auki
# Processing Record 27 of Set 5 | basi
# Processing Record 28 of Set 5 | kharan
# Processing Record 29 of Set 5 | quang ngai
# Processing Record 30 of Set 5 | surt
# Processing Record 31 of Set 5 | mudu
# Processing Record 32 of Set 5 | san pedro
# Processing Record 33 of Set 5 | trinidad
# Processing Record 34 of Set 5 | lebu
# Processing Record 35 of Set 5 | aden
# Processing Record 36 of Set 5 | najran
# Processing Record 37 of Set 5 | charters towers
# Processing Record 38 of Set 5 | tuktoyaktuk
# Processing Record 39 of Set 5 | faya
# Processing Record 40 of Set 5 | ucluelet
# Processing Record 41 of Set 5 | college
# Processing Record 42 of Set 5 | linqiong
# Processing Record 43 of Set 5 | pau
# Processing Record 44 of Set 5 | santa vitoria do palmar
# Processing Record 45 of Set 5 | aklavik
# Processing Record 46 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 5 | bambous virieux
# Processing Record 48 of Set 5 | almirante
# Processing Record 49 of Set 5 | ola
# Processing Record 50 of Set 5 | magrath
# Processing Record 1 of Set 6 | port alfred
# Processing Record 2 of Set 6 | buchanan
# Processing Record 3 of Set 6 | laguna
# Processing Record 4 of Set 6 | mount barker
# Processing Record 5 of Set 6 | qaqortoq
# Processing Record 6 of Set 6 | bauru
# Processing Record 7 of Set 6 | buala
# Processing Record 8 of Set 6 | bouake
# Processing Record 9 of Set 6 | fort-shevchenko
# Processing Record 10 of Set 6 | xining
# Processing Record 11 of Set 6 | pisco
# Processing Record 12 of Set 6 | katsuura
# Processing Record 13 of Set 6 | urengoy
# Processing Record 14 of Set 6 | alta
# Processing Record 15 of Set 6 | nicoya
# Processing Record 16 of Set 6 | puerto carreno
# Processing Record 17 of Set 6 | novo aripuana
# Processing Record 18 of Set 6 | hasaki
# Processing Record 19 of Set 6 | salalah
# Processing Record 20 of Set 6 | sharanga
# Processing Record 21 of Set 6 | conde
# Processing Record 22 of Set 6 | lukovo
# Processing Record 23 of Set 6 | palmer
# Processing Record 24 of Set 6 | buta
# Processing Record 25 of Set 6 | gat
# Processing Record 26 of Set 6 | okato
# Processing Record 27 of Set 6 | fuling
# Processing Record 28 of Set 6 | jaypur
# Processing Record 29 of Set 6 | ballina
# Processing Record 30 of Set 6 | nouadhibou
# Processing Record 31 of Set 6 | constitucion
# Processing Record 32 of Set 6 | gympie
# Processing Record 33 of Set 6 | carnarvon
# Processing Record 34 of Set 6 | broome
# Processing Record 35 of Set 6 | ngunguru
# Processing Record 36 of Set 6 | kiruna
# Processing Record 37 of Set 6 | yumen
# Processing Record 38 of Set 6 | sobolevo
# Processing Record 39 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 6 | necochea
# Processing Record 41 of Set 6 | kahului
# Processing Record 42 of Set 6 | gonda
# Processing Record 43 of Set 6 | shetpe
# Processing Record 44 of Set 6 | togur
# Processing Record 45 of Set 6 | tarauaca
# Processing Record 46 of Set 6 | port elizabeth
# Processing Record 47 of Set 6 | pangnirtung
# Processing Record 48 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 49 of Set 6 | ancud
# Processing Record 50 of Set 6 | rafaela
# Processing Record 1 of Set 7 | irbil
# Processing Record 2 of Set 7 | komsomolskiy
# Processing Record 3 of Set 7 | requena
# Processing Record 4 of Set 7 | victoria
# Processing Record 5 of Set 7 | boca do acre
# Processing Record 6 of Set 7 | floro
# Processing Record 7 of Set 7 | flinders
# Processing Record 8 of Set 7 | iskele
# Processing Record 9 of Set 7 | klyuchi
# Processing Record 10 of Set 7 | bairiki
# Processing Record 11 of Set 7 | comodoro rivadavia
# Processing Record 12 of Set 7 | eirunepe
# Processing Record 13 of Set 7 | beian
# Processing Record 14 of Set 7 | magistralnyy
# Processing Record 15 of Set 7 | pokaran
# Processing Record 16 of Set 7 | colon
# Processing Record 17 of Set 7 | sawtell
# Processing Record 18 of Set 7 | san juan
# Processing Record 19 of Set 7 | moose factory
# Processing Record 20 of Set 7 | hwange
# Processing Record 21 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 23 of Set 7 | solnechnyy
# Processing Record 24 of Set 7 | kommunar
# Processing Record 25 of Set 7 | mount gambier
# Processing Record 26 of Set 7 | ormara
# Processing Record 27 of Set 7 | craig
# Processing Record 28 of Set 7 | jieshi
# Processing Record 29 of Set 7 | artyom
# Processing Record 30 of Set 7 | demba
# Processing Record 31 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 7 | almeirim
# Processing Record 33 of Set 7 | camabatela
# Processing Record 34 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 35 of Set 7 | moyale
# Processing Record 36 of Set 7 | ambilobe
# Processing Record 37 of Set 7 | coruripe
# Processing Record 38 of Set 7 | port washington
# Processing Record 39 of Set 7 | padang
# Processing Record 40 of Set 7 | sitka
# Processing Record 41 of Set 7 | okaihau
# Processing Record 42 of Set 7 | fomboni
# Processing Record 43 of Set 7 | christchurch
# Processing Record 44 of Set 7 | chatellerault
# Processing Record 45 of Set 7 | akyab
# Processing Record 46 of Set 7 | thinadhoo
# Processing Record 47 of Set 7 | kangaatsiaq
# Processing Record 48 of Set 7 | nongan
# Processing Record 49 of Set 7 | vuktyl
# Processing Record 50 of Set 7 | makakilo city
# Processing Record 1 of Set 8 | zhuhai
# Processing Record 2 of Set 8 | wanning
# Processing Record 3 of Set 8 | poya
# Processing Record 4 of Set 8 | bielsko-biala
# Processing Record 5 of Set 8 | khandyga
# Processing Record 6 of Set 8 | cardston
# Processing Record 7 of Set 8 | suamico
# Processing Record 8 of Set 8 | mehamn
# Processing Record 9 of Set 8 | ust-nera
# Processing Record 10 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 11 of Set 8 | tigil
# Processing Record 12 of Set 8 | mandalgovi
# Processing Record 13 of Set 8 | corinto
# Processing Record 14 of Set 8 | igdir
# Processing Record 15 of Set 8 | dingle
# Processing Record 16 of Set 8 | bandarbeyla
# Processing Record 17 of Set 8 | san rafael
# Processing Record 18 of Set 8 | gotsu
# Processing Record 19 of Set 8 | piacabucu
# Processing Record 20 of Set 8 | mugur-aksy
# Processing Record 21 of Set 8 | anadyr
# Processing Record 22 of Set 8 | mayo
# Processing Record 23 of Set 8 | yerbogachen
# Processing Record 24 of Set 8 | linhares
# Processing Record 25 of Set 8 | iskateley
# Processing Record 26 of Set 8 | yining
# Processing Record 27 of Set 8 | kacarevo
# Processing Record 28 of Set 8 | katsiveli
# City not found. Skipping...
# Processing Record 29 of Set 8 | ocumare del tuy
# Processing Record 30 of Set 8 | beitbridge
# Processing Record 31 of Set 8 | coquimbo
# Processing Record 32 of Set 8 | grindavik
# Processing Record 33 of Set 8 | guadalupe victoria
# Processing Record 34 of Set 8 | kangalassy
# Processing Record 35 of Set 8 | katobu
# Processing Record 36 of Set 8 | lasa
# Processing Record 37 of Set 8 | faanui
# Processing Record 38 of Set 8 | solovetskiy
# City not found. Skipping...
# Processing Record 39 of Set 8 | kieta
# Processing Record 40 of Set 8 | waipawa
# Processing Record 41 of Set 8 | ponte nova
# Processing Record 42 of Set 8 | ziway
# Processing Record 43 of Set 8 | praia da vitoria
# Processing Record 44 of Set 8 | nanortalik
# Processing Record 45 of Set 8 | jumla
# Processing Record 46 of Set 8 | pangai
# Processing Record 47 of Set 8 | kovdor
# Processing Record 48 of Set 8 | kaithal
# Processing Record 49 of Set 8 | chapada dos guimaraes
# Processing Record 50 of Set 8 | santa fe
# Processing Record 1 of Set 9 | kilindoni
# Processing Record 2 of Set 9 | maceio
# Processing Record 3 of Set 9 | port augusta
# Processing Record 4 of Set 9 | martapura
# Processing Record 5 of Set 9 | bullhead city
# Processing Record 6 of Set 9 | henties bay
# Processing Record 7 of Set 9 | vestmannaeyjar
# Processing Record 8 of Set 9 | ayagoz
# Processing Record 9 of Set 9 | hervey bay
# Processing Record 10 of Set 9 | sassandra
# Processing Record 11 of Set 9 | chalmette
# Processing Record 12 of Set 9 | kruisfontein
# Processing Record 13 of Set 9 | kununurra
# Processing Record 14 of Set 9 | ambovombe
# Processing Record 15 of Set 9 | santa rosa
# Processing Record 16 of Set 9 | alekseyevka
# Processing Record 17 of Set 9 | kysyl-syr
# Processing Record 18 of Set 9 | cumbitara
# Processing Record 19 of Set 9 | tuatapere
# Processing Record 20 of Set 9 | goure
# Processing Record 21 of Set 9 | oum hadjer
# Processing Record 22 of Set 9 | russell
# Processing Record 23 of Set 9 | saint-pascal
# City not found. Skipping...
# Processing Record 24 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 25 of Set 9 | ostrovnoy
# Processing Record 26 of Set 9 | gweta
# Processing Record 27 of Set 9 | tukrah
# Processing Record 28 of Set 9 | agadez
# Processing Record 29 of Set 9 | geilo
# Processing Record 30 of Set 9 | adrar
# Processing Record 31 of Set 9 | verkhoyansk
# Processing Record 32 of Set 9 | boa vista
# Processing Record 33 of Set 9 | dolores
# Processing Record 34 of Set 9 | ouadda
# Processing Record 35 of Set 9 | kinablangan
# Processing Record 36 of Set 9 | bafilo
# Processing Record 37 of Set 9 | raudeberg
# Processing Record 38 of Set 9 | bocaiuva
# Processing Record 39 of Set 9 | lahat
# Processing Record 40 of Set 9 | waingapu
# Processing Record 41 of Set 9 | waitati
# Processing Record 42 of Set 9 | burg
# Processing Record 43 of Set 9 | healdsburg
# Processing Record 44 of Set 9 | coahuayana
# Processing Record 45 of Set 9 | avera
# Processing Record 46 of Set 9 | itarema
# Processing Record 47 of Set 9 | cairns
# Processing Record 48 of Set 9 | tumaco
# Processing Record 49 of Set 9 | srednekolymsk
# Processing Record 50 of Set 9 | kulachi
# Processing Record 1 of Set 10 | san sebastian
# Processing Record 2 of Set 10 | vilshofen
# Processing Record 3 of Set 10 | yenagoa
# Processing Record 4 of Set 10 | biak
# Processing Record 5 of Set 10 | harper
# Processing Record 6 of Set 10 | jiexiu
# Processing Record 7 of Set 10 | arman
# Processing Record 8 of Set 10 | lensk
# Processing Record 9 of Set 10 | kiama
# Processing Record 10 of Set 10 | kodinsk
# Processing Record 11 of Set 10 | petropavl
# Processing Record 12 of Set 10 | prachuap khiri khan
# Processing Record 13 of Set 10 | rio gallegos
# Processing Record 14 of Set 10 | joshimath
# Processing Record 15 of Set 10 | vila do maio
# Processing Record 16 of Set 10 | basco
# Processing Record 17 of Set 10 | finschhafen
# Processing Record 18 of Set 10 | manggar
# Processing Record 19 of Set 10 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 20 of Set 10 | senno
# Processing Record 21 of Set 10 | bartica
# Processing Record 22 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 23 of Set 10 | katsina
# Processing Record 24 of Set 10 | brae
# Processing Record 25 of Set 10 | ruza
# Processing Record 26 of Set 10 | pangody
# Processing Record 27 of Set 10 | changqing
# Processing Record 28 of Set 10 | vanersborg
# Processing Record 29 of Set 10 | walvis bay
# Processing Record 30 of Set 10 | altay
# Processing Record 31 of Set 10 | nikolskoye
# Processing Record 32 of Set 10 | bad sachsa
# Processing Record 33 of Set 10 | homer
# Processing Record 34 of Set 10 | inhambane
# Processing Record 35 of Set 10 | souris
# Processing Record 36 of Set 10 | san nicolas
# Processing Record 37 of Set 10 | cedar city
# Processing Record 38 of Set 10 | eureka
# Processing Record 39 of Set 10 | amalapuram
# Processing Record 40 of Set 10 | salon-de-provence
# Processing Record 41 of Set 10 | fort nelson
# Processing Record 42 of Set 10 | svetlyy
# Processing Record 43 of Set 10 | balkanabat
# Processing Record 44 of Set 10 | alghero
# Processing Record 45 of Set 10 | tongzi
# Processing Record 46 of Set 10 | beringovskiy
# Processing Record 47 of Set 10 | caravelas
# Processing Record 48 of Set 10 | kalabo
# Processing Record 49 of Set 10 | kolpashevo
# Processing Record 50 of Set 10 | matara
# Processing Record 1 of Set 11 | burica
# City not found. Skipping...
# Processing Record 2 of Set 11 | high level
# Processing Record 3 of Set 11 | maningrida
# Processing Record 4 of Set 11 | dali
# Processing Record 5 of Set 11 | alappuzha
# Processing Record 6 of Set 11 | los chiles
# Processing Record 7 of Set 11 | clarence town
# Processing Record 8 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 11 | abu samrah
# Processing Record 10 of Set 11 | rawson
# Processing Record 11 of Set 11 | emerald
# Processing Record 12 of Set 11 | biltine
# Processing Record 13 of Set 11 | nibbar
# Processing Record 14 of Set 11 | namibe
# Processing Record 15 of Set 11 | stjordalshalsen
# Processing Record 16 of Set 11 | puerto del rosario
# Processing Record 17 of Set 11 | sungaipenuh
# Processing Record 18 of Set 11 | merrill
# Processing Record 19 of Set 11 | ahipara
# Processing Record 20 of Set 11 | mataram
# Processing Record 21 of Set 11 | hammerfest
# Processing Record 22 of Set 11 | watertown
# Processing Record 23 of Set 11 | beloha
# Processing Record 24 of Set 11 | aromashevo
# Processing Record 25 of Set 11 | varhaug
# Processing Record 26 of Set 11 | hualmay
# Processing Record 27 of Set 11 | port lincoln
# Processing Record 28 of Set 11 | fairbanks
# Processing Record 29 of Set 11 | severo-yeniseyskiy
# Processing Record 30 of Set 11 | sibolga
# Processing Record 31 of Set 11 | esso
# Processing Record 32 of Set 11 | saldanha
# Processing Record 33 of Set 11 | gizo
# Processing Record 34 of Set 11 | innisfail
# Processing Record 35 of Set 11 | meadow lake
# Processing Record 36 of Set 11 | kamenka
# Processing Record 37 of Set 11 | formosa
# Processing Record 38 of Set 11 | gao
# Processing Record 39 of Set 11 | mpika
# Processing Record 40 of Set 11 | el carmen
# Processing Record 41 of Set 11 | montivilliers
# Processing Record 42 of Set 11 | banjar
# Processing Record 43 of Set 11 | sinnamary
# Processing Record 44 of Set 11 | vestmanna
# Processing Record 45 of Set 11 | uige
# Processing Record 46 of Set 11 | soyo
# Processing Record 47 of Set 11 | duns
# Processing Record 48 of Set 11 | pacific grove
# Processing Record 49 of Set 11 | bubaque
# Processing Record 50 of Set 11 | bodden town
# Processing Record 1 of Set 12 | pocoes
# Processing Record 2 of Set 12 | maragogi
# Processing Record 3 of Set 12 | bellevue
# Processing Record 4 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 5 of Set 12 | hami
# Processing Record 6 of Set 12 | gorom-gorom
# Processing Record 7 of Set 12 | liverpool
# Processing Record 8 of Set 12 | tabuk
# Processing Record 9 of Set 12 | puerto leguizamo
# Processing Record 10 of Set 12 | ukiah
# Processing Record 11 of Set 12 | trairi
# Processing Record 12 of Set 12 | lekoni
# Processing Record 13 of Set 12 | caraballeda
# Processing Record 14 of Set 12 | maneadero
# Processing Record 15 of Set 12 | maputo
# Processing Record 16 of Set 12 | uryupinsk
# Processing Record 17 of Set 12 | sarkand
# Processing Record 18 of Set 12 | korla
# Processing Record 19 of Set 12 | valenca
# Processing Record 20 of Set 12 | namatanai
# Processing Record 21 of Set 12 | kamaishi
# Processing Record 22 of Set 12 | lososina
# Processing Record 23 of Set 12 | canakkale
# Processing Record 24 of Set 12 | plattsburgh
# Processing Record 25 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 26 of Set 12 | westport
# Processing Record 27 of Set 12 | poum
# Processing Record 28 of Set 12 | skjervoy
# Processing Record 29 of Set 12 | dawei
# Processing Record 30 of Set 12 | safford
# Processing Record 31 of Set 12 | mocuba
# Processing Record 32 of Set 12 | tigzirt
# Processing Record 33 of Set 12 | villarrica
# Processing Record 34 of Set 12 | aksay
# Processing Record 35 of Set 12 | gazanjyk
# Processing Record 36 of Set 12 | atherton
# Processing Record 37 of Set 12 | outjo
# Processing Record 38 of Set 12 | panguna
# Processing Record 39 of Set 12 | saint anthony
# Processing Record 40 of Set 12 | kirakira
# Processing Record 41 of Set 12 | benghazi
# Processing Record 42 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 12 | ghiror
# Processing Record 44 of Set 12 | yar-sale
# Processing Record 45 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 46 of Set 12 | nishihara
# Processing Record 47 of Set 12 | susaki
# Processing Record 48 of Set 12 | auch
# Processing Record 49 of Set 12 | qrendi
# Processing Record 50 of Set 12 | derzhavinsk
# Processing Record 1 of Set 13 | pryazha
# Processing Record 2 of Set 13 | black river
# Processing Record 3 of Set 13 | apex
# Processing Record 4 of Set 13 | ulagan
# Processing Record 5 of Set 13 | izhma
# Processing Record 6 of Set 13 | cap malheureux
# Processing Record 7 of Set 13 | taua
# Processing Record 8 of Set 13 | bacolod
# Processing Record 9 of Set 13 | zhigansk
# Processing Record 10 of Set 13 | hovd
# Processing Record 11 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 13 | beyneu
# Processing Record 13 of Set 13 | rongcheng
# Processing Record 14 of Set 13 | bure
# Processing Record 15 of Set 13 | marathon
# Processing Record 16 of Set 13 | bilibino
# Processing Record 17 of Set 13 | dmitriyevskoye
# Processing Record 18 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 13 | ust-kan
# Processing Record 20 of Set 13 | lebane
# Processing Record 21 of Set 13 | siwana
# Processing Record 22 of Set 13 | acari
# Processing Record 23 of Set 13 | salobrena
# Processing Record 24 of Set 13 | manacor
# Processing Record 25 of Set 13 | san-pedro
# Processing Record 26 of Set 13 | canguaretama
# Processing Record 27 of Set 13 | watrous
# Processing Record 28 of Set 13 | iquique
# Processing Record 29 of Set 13 | leh
# Processing Record 30 of Set 13 | bani walid
# Processing Record 31 of Set 13 | tonosho
# Processing Record 32 of Set 13 | los llanos de aridane
# Processing Record 33 of Set 13 | pingshan
# Processing Record 34 of Set 13 | talcher
# Processing Record 35 of Set 13 | khash
# Processing Record 36 of Set 13 | kirensk
# Processing Record 37 of Set 13 | san francisco del mar
# Processing Record 38 of Set 13 | araguatins
# City not found. Skipping...
# Processing Record 39 of Set 13 | selma
# Processing Record 40 of Set 13 | cayenne
# Processing Record 41 of Set 13 | juan lacaze
# Processing Record 42 of Set 13 | siguiri
# Processing Record 43 of Set 13 | asayita
# City not found. Skipping...
# Processing Record 44 of Set 13 | umm lajj
# Processing Record 45 of Set 13 | boa esperanca
# Processing Record 46 of Set 13 | baghdad
# Processing Record 47 of Set 13 | pontianak
# Processing Record 48 of Set 13 | juegang
# Processing Record 49 of Set 13 | whitehorse
# Processing Record 50 of Set 13 | teodoro sampaio
# Processing Record 1 of Set 14 | plettenberg bay
# Processing Record 2 of Set 14 | longkou
# Processing Record 3 of Set 14 | baykit
# Processing Record 4 of Set 14 | ayolas
# Processing Record 5 of Set 14 | guadalupe y calvo
# Processing Record 6 of Set 14 | swift current
# Processing Record 7 of Set 14 | lexington
# Processing Record 8 of Set 14 | lorengau
# Processing Record 9 of Set 14 | kumano
# Processing Record 10 of Set 14 | valdivia
# Processing Record 11 of Set 14 | vizinga
# Processing Record 12 of Set 14 | dodge city
# Processing Record 13 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 14 | pandan
# Processing Record 15 of Set 14 | damghan
# Processing Record 16 of Set 14 | conceicao da barra
# Processing Record 17 of Set 14 | karagay
# Processing Record 18 of Set 14 | ayni
# Processing Record 19 of Set 14 | komsomolets
# Processing Record 20 of Set 14 | ardakan
# Processing Record 21 of Set 14 | mezen
# Processing Record 22 of Set 14 | micheweni
# Processing Record 23 of Set 14 | nagua
# Processing Record 24 of Set 14 | orcopampa
# Processing Record 25 of Set 14 | dobryanka
# Processing Record 26 of Set 14 | ternate
# Processing Record 27 of Set 14 | miri
# Processing Record 28 of Set 14 | watsa
# Processing Record 29 of Set 14 | mangochi
# Processing Record 30 of Set 14 | carman
# Processing Record 31 of Set 14 | effium
# Processing Record 32 of Set 14 | si sa ket
# Processing Record 33 of Set 14 | loiza
# Processing Record 34 of Set 14 | salinopolis
# Processing Record 35 of Set 14 | coos bay
# Processing Record 36 of Set 14 | sestri levante
# Processing Record 37 of Set 14 | hongjiang
# Processing Record 38 of Set 14 | mujiayingzi
# Processing Record 39 of Set 14 | tazovskiy
# Processing Record 40 of Set 14 | matay
# Processing Record 41 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 14 | nizwa
# Processing Record 43 of Set 14 | alyangula
# Processing Record 44 of Set 14 | ilo
# Processing Record 45 of Set 14 | ulaangom
# Processing Record 46 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 14 | shenzhen
# Processing Record 48 of Set 14 | toba
# Processing Record 49 of Set 14 | zorritos
# Processing Record 50 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 1 of Set 15 | tateyama
# Processing Record 2 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 3 of Set 15 | acarau
# Processing Record 4 of Set 15 | the pas
# Processing Record 5 of Set 15 | takoradi
# Processing Record 6 of Set 15 | kidal
# Processing Record 7 of Set 15 | fez
# Processing Record 8 of Set 15 | bull savanna
# Processing Record 9 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 10 of Set 15 | sezze
# Processing Record 11 of Set 15 | sliac
# City not found. Skipping...
# Processing Record 12 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 13 of Set 15 | port hardy
# Processing Record 14 of Set 15 | zhoucheng
# Processing Record 15 of Set 15 | point pedro
# Processing Record 16 of Set 15 | champerico
# Processing Record 17 of Set 15 | luchegorsk
# Processing Record 18 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 19 of Set 15 | tayu
# Processing Record 20 of Set 15 | tamandare
# Processing Record 21 of Set 15 | paita
# Processing Record 22 of Set 15 | cam ranh
# Processing Record 23 of Set 15 | gimli
# Processing Record 24 of Set 15 | ingham
# Processing Record 25 of Set 15 | sola
# Processing Record 26 of Set 15 | aras
# Processing Record 27 of Set 15 | xinyang
# Processing Record 28 of Set 15 | aykhal
# Processing Record 29 of Set 15 | hirara
# Processing Record 30 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 15 | eyl
# Processing Record 32 of Set 15 | jiquipilas
# Processing Record 33 of Set 15 | davila
# Processing Record 34 of Set 15 | show low
# Processing Record 35 of Set 15 | urucara
# Processing Record 36 of Set 15 | egvekinot
# Processing Record 37 of Set 15 | sulangan
# Processing Record 38 of Set 15 | sayyan
# Processing Record 39 of Set 15 | roma
# Processing Record 40 of Set 15 | sisimiut
# Processing Record 41 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 42 of Set 15 | khonsa
# Processing Record 43 of Set 15 | varzea da palma
# Processing Record 44 of Set 15 | tver
# Processing Record 45 of Set 15 | bonoua
# Processing Record 46 of Set 15 | lasem
# Processing Record 47 of Set 15 | waddan
# Processing Record 48 of Set 15 | cermik
# Processing Record 49 of Set 15 | igarka
# Processing Record 50 of Set 15 | la rioja
# Processing Record 1 of Set 16 | riyaq
# City not found. Skipping...
# Processing Record 2 of Set 16 | sabha
# Processing Record 3 of Set 16 | byron bay
# Processing Record 4 of Set 16 | sadao
# Processing Record 5 of Set 16 | ust-ilimsk
# Processing Record 6 of Set 16 | udachnyy
# Processing Record 7 of Set 16 | kedrovyy
# Processing Record 8 of Set 16 | ndioum
# Processing Record 9 of Set 16 | puerto baquerizo moreno
# Processing Record 10 of Set 16 | oliva
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 706

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp      Weather Description  \
# 0            Alofi -19.0595 -169.9187     78.69            broken clouds
# 1          Ushuaia -54.8000  -68.3000     53.26            broken clouds
# 2     Richards Bay -28.7830   32.0377     70.97                clear sky
# 3            Vaini -21.2000 -175.2000     80.76  light intensity drizzle
# 4             Kaeo -35.1000  173.7833     72.32               few clouds
# 5           Avarua -21.2078 -159.7750     80.65            broken clouds
# 6   Saint-Augustin  51.2260  -58.6502     10.72          overcast clouds
# 7  Arraial Do Cabo -22.9661  -42.0278     74.43          overcast clouds
# 8     San Patricio  28.0170  -97.5169     69.89            broken clouds
# 9          Peniche  39.3558   -9.3811     56.10          overcast clouds
#
#    Humidity  Cloudiness  Wind Speed Country
# 0        83          52        5.75      NU
# 1        58          75        5.75      AR
# 2        95           4        5.17      ZA
# 3        94          75        8.05      TO
# 4        70          24       13.73      NZ
# 5        69          75        6.91      CK
# 6        84         100        6.69      CA
# 7        90          94       24.34      BR
# 8        72          74       19.86      US
# 9        72         100       20.54      PT

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Weather Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Weather Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Alofi      NU -19.0595 -169.9187     78.69        83          52
# 1       Ushuaia      AR -54.8000  -68.3000     53.26        58          75
# 2  Richards Bay      ZA -28.7830   32.0377     70.97        95           4
# 3         Vaini      TO -21.2000 -175.2000     80.76        94          75
# 4          Kaeo      NZ -35.1000  173.7833     72.32        70          24
#
#    Wind Speed      Weather Description
# 0        5.75            broken clouds
# 1        5.75            broken clouds
# 2        5.17                clear sky
# 3        8.05  light intensity drizzle
# 4       13.73               few clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Weather Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = 'weatherpy_database.csv'

# %%
# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file)
